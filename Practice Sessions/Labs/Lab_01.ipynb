# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from PIL import Image
from skimage import io

# %%
def computeNegativeImage(image):
    negImg = np.abs(image-255)
    return(negImg)

# %%
url = "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg"
img = io.imread(url)
img = np.array(img)
img = img.astype("int")

# %%
plt.imshow(img, cmap=plt.get_cmap('gray'))
plt.title("orignal Image")
plt.show()

# %%
plt.hist(img.ravel(), bins = 256, range = [0,256])
plt.show()
color  = ('b','g','r')
for i, cols in enumerate(color):
    hist = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(hist, color = cols)
plt.xlim([0,256])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 5
#       3 color  = ('b','g','r')
#       4 for i, cols in enumerate(color):
# ----> 5     hist = cv2.calcHist([img],[i],None,[256],[0,256])
#       6     plt.plot(hist, color = cols)
#       7 plt.xlim([0,256])
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\histogram.cpp:1008: error: (-210:Unsupported format or combination of formats)  in function 'cv::calcHist'

# %%
color  = ('b','g','r')
for i, cols in enumerate(color):
    print(type([img]))
    hist = cv2.calcHist(img,[i],None,[256],[0,256])
    plt.plot(hist, color = cols)
plt.xlim([0,256])
plt.show()
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 4
#       2 for i, cols in enumerate(color):
#       3     print(type([img]))
# ----> 4     hist = cv2.calcHist(img,[i],None,[256],[0,256])
#       5     plt.plot(hist, color = cols)
#       6 plt.xlim([0,256])
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\histogram.cpp:1008: error: (-210:Unsupported format or combination of formats)  in function 'cv::calcHist'
